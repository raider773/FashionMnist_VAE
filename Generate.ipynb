# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
import pickle
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from conf.settings import Settings
from estimator.estimatorUtils import callbacks,plot_latent_space,morph
from estimator.VAE import VariationalAutoEncoder
from utils.utils import show_pictures,create_folder,process_data,show_reconstructed

# %%
settings = Settings()

# %%
metrics_folder = settings.metrics_folder
model_folder = settings.model_folder

latent_space = settings.latent_space
amount_to_generate = settings.amount_to_generate
amount_of_vector_multipliers = settings.amount_of_vector_multipliers

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train, y_train,x_test, y_test = process_data(x_train, y_train,x_test, y_test)

# %%
estimator = VariationalAutoEncoder()
# Out:
# WARNING:tensorflow:From C:\Users\gonzalo\.conda\envs\generative_pokemon\lib\site-packages\keras\layers\normalization\batch_normalization.py:562: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
estimator.full_model.load_weights(model_folder + "/vae_weights.h5")

# %%
generation = estimator.decoder.predict(np.random.normal(size = (amount_to_generate,latent_space)))
y = np.full((amount_to_generate), "Generated",dtype=object)
# Out:
# C:\Users\gonzalo\.conda\envs\generative_pokemon\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
show_pictures(generation,y)

# %%
show_pictures(generation,y)

# %%
show_pictures(generation,y)

# %%
morph(x_train,y_train,4,1,estimator,amount_of_vector_multipliers)

# %%
morph(x_train,y_train,7,9,estimator,amount_of_vector_multipliers)

# %%
morph(x_train,y_train,6,8,estimator,amount_of_vector_multipliers)

# %%
morph(x_train,y_train,0,1,estimator,amount_of_vector_multipliers)
